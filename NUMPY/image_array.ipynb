# %%
import numpy as np #nd array

# %%
import matplotlib.pyplot as plt #visualizations

# %%
from PIL import Image #Python image library

# %%
image=Image.open(r'C:\Users\hp\Desktop\pic.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=305x165>

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image_arr=np.asarray(image)
image_arr
# Out:
# array([[[210, 214, 215],
#         [210, 214, 215],
#         [210, 214, 215],
#         ...,
#         [152, 170, 182],
#         [151, 169, 181],
#         [149, 168, 182]],
#
#        [[212, 216, 217],
#         [212, 216, 217],
#         [212, 216, 217],
#         ...,
#         [150, 168, 180],
#         [149, 168, 182],
#         [145, 164, 178]],
#
#        [[215, 219, 220],
#         [215, 219, 220],
#         [215, 219, 220],
#         ...,
#         [147, 166, 180],
#         [145, 167, 180],
#         [138, 160, 174]],
#
#        ...,
#
#        [[102, 118,  47],
#         [121, 137,  64],
#         [122, 135,  63],
#         ...,
#         [ 67,  78,  20],
#         [ 80,  91,  33],
#         [ 96, 104,  47]],
#
#        [[120, 136,  65],
#         [129, 145,  72],
#         [130, 143,  71],
#         ...,
#         [ 50,  61,   3],
#         [ 60,  71,  13],
#         [ 81,  89,  30]],
#
#        [[124, 140,  69],
#         [130, 146,  73],
#         [138, 151,  79],
#         ...,
#         [ 76,  87,  29],
#         [103, 114,  54],
#         [136, 144,  84]]], shape=(165, 305, 3), dtype=uint8)

# %%
plt.imshow(image_arr)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
image_arr.shape
# Out:
# (165, 305, 3)
