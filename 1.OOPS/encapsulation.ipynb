# %%
#instance variable

# %%
class car:
    def __init__(self):
        self.mil = 10
        self.com = 'bmw'
        
c1 = car()
c2 = car()

print(c1.com, c1.mil)
print(c2.com, c2.mil)
# Out:
# bmw 10
# bmw 10

# %%
class car:
    def __init__(self):
        self.mil = 10
        self.com = 'bmw'
        
c1 = car()
c2 = car()

c1.mil = 9
c2.mil = 5

print(c1.com, c1.mil)
print(c2.com, c2.mil)
# Out:
# bmw 9
# bmw 5

# %%
class car:
    def __init__(self):
        self.mil = 10
        self.com = 'bmw'
        
c1 = car()
c2 = car()

c1.mil = 9
c2.mil = 18
c2.com = 'asian_cars'

print(c1.com, c1.mil)
print(c2.com, c2.mil)
# Out:
# bmw 9
# asian_cars 18

# %%
class car:

    wheels = 5 # class variable or static variable 
    
    def __init__(self):
        self.mil = 10 # instance variable 
        self.com = 'bmw' #instance variable 
        
c1 = car()
c2 = car()

c1.wheels = 6

print(c1.wheels, c1.com)
# Out:
# 6 bmw

# %%
#Encapsulation moethods

# %%
class student(): 
        
    school = 'nit'   
    
    def __init__(self, m1, m2, m3) : 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    

s1 = student(10, 20, 30)
s2 = student(5, 15, 10)

print(s1.avg())
print(s2.avg())
# Out:
# 20.0
# 10.0

# %%
class student(): 
         
    school = 'nit'
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
# lets create  object hear as we created s1, s2 we created 2 object & also i want to pass value in this  
s1 = student(10, 20, 30)
s2 = student(5, 15, 10)

print(s1.avg())
print(s2.avg())
# Out:
# 20.0
# 10.0

# %%
class student(): 
        
    school = 'nit'
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
    def info(cls): # user need to define cls - for class variable 
        return cls.school 
        
# lets create  object hear as we created s1, s2 we created 2 object & also i want to pass value in this  
s1 = student(10, 20, 30)
s2 = student(5, 15, 10)

print(s1.avg())  # instance method it calls instance variable 
(s1.info()) # class method cuz it call class variable
# Out:
# 20.0
# 'nit'

# %%
class student(): 
        
    school = 'nit'
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
    @classmethod
    def info(cls): # user need to define cls - for class variable 
        return cls.school 
        

s1 = student(10, 20, 30)
s2 = student(5, 15, 10)

s1.info() 
s2.avg()
# Out:
# 10.0

# %%
class student(): 
        
    school = 'nit' 
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
    @classmethod
    def getSchool(cls):
        return cls.school
    
    @staticmethod # this student class nothing to do any class & for that also u need to pass speciasl decorator
    def info():
        print('this is student class') 
        
# lets create  object hear as we created s1, s2 we created 2 object & also i want to pass value in this  
s1 = student(10, 20, 30)
s2 = student(5, 15, 10)

s1.avg()
s1.info()
# Out:
# this is student class

# %%
class student():
    def __init__(self, name, rollno):
        self.name = name
        self.rollno = rollno
     
s1 = student('a',1)
s2 = student('b',2)

print(s1.name, s1.rollno) 
print(s2.name, s2.rollno)
# Out:
# a 1
# b 2

# %%
class student:
    def __init__(self, name, rollno):
        self.name = name
        self.rollno = rollno
        
    def show(self):
        print(s1.name, s1.rollno)
        print(s2.name)
        
     
s1 = student('a',1)
s2 = student('b',2)

s1.show()
# Out:
# a 1
# b

# %%
class student:
    def __init__(self, name, rollno):
        self.name = name
        self.rollno = rollno
        
    def show(self):
        print(s1.name, s2.rollno)
     
s1 = student('a',1,'hp','i5', 8) # the moment when we assign the variable we need to assign the class as well 
s2 = student('b',2)

s1.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 9
#       5
#       6     def show(self):
#       7         print(s1.name, s2.rollno)
#       8
# ----> 9 s1 = student('a',1,'hp','i5', 8) # the moment when we assign the variable we need to assign the class as well
#      10 s2 = student('b',2)
#      11
#      12 s1.show()
#
# TypeError: student.__init__() takes 3 positional arguments but 6 were given

# %%
class student:
    def __init__(self, name, rollno, laptop, cpu, ram):
        self.name = name
        self.rollno = rollno
        self.laptop = laptop
        self.cpu = cpu
        self.ram = ram
        
    def show(self):
        print(s1.name, s1.rollno,s1.laptop, s1.cpu, s1.ram)
        print(s2.name, s2.rollno,s2.laptop, s2.cpu, s2.ram)

s1 = student('a',1,'lenovo','i5',8) # the moment when we assign the variable we need to assign the class as well 
s2 = student('b',2,'hp','i7',16)

s2.show()
# Out:
# a 1 lenovo i5 8
# b 2 hp i7 16

# %%
class Student:

    def __init__(self, name, age, wife, sal):
        self.name = name
        self.age = age

        # creating object of inner class
        self.kids = self.Kids(wife, sal)

    def mar(self):
        print(self.name, self.age)

    class Kids:
        def __init__(self, wife, sal):
            self.wife = wife
            self.sal = sal

        def anu(self):
            print(self.wife, self.sal)


s1 = Student('Manikanta', 28, 'Anu', 50000)

s1.mar()

# calling inner class method
s1.kids.anu()
# Out:
# Manikanta 28
# Anu 50000

# %%
class student:
    def __init__(self, name, rollno):
        self.name = name
        self.rollno = rollno
        
        #self.lap = self.LAPTOP()
        
    def show(self):
        print(self.name, self.rollno)
        
    class LAPTOP:
        def __init__(self):
            self.brand = 'hp'
            self.cpu = 'i5'
            self.ram = 8
     
s1 = student('a',1) # the moment when we assign the variable we need to assign the class as well 
s2 = student('b',2)

s1.show()
s2.show()


#lap1 = s1.lap
#lap2 = s2.lap

#print(id(lap1))
#print(id(lap2))
# Out:
# a 1
# b 2

# %%
class student:
    def __init__(self, name, rollno):
        self.name = name
        self.rollno = rollno
        
        self.lap = self.LAPTOP()
        
    def show(self):
        print(self.name, self.rollno)
        
    class LAPTOP:
        def __init__(self):
            self.brand = 'hp'
            self.cpu = 'i5'
            self.ram = 8
     
s1 = student('a',1) # the moment when we assign the variable we need to assign the class as well 
s2 = student('b',2)

s1.show()
s2.show()


lap1 = s1.lap
lap2 = s2.lap

print(id(lap1))
print(id(lap2))
# Out:
# a 1
# b 2
# 2841259065616
# 2841259747728

# %%
class student:
    def __init__(self, name, rollno):
        self.name = name
        self.rollno = rollno
        
        self.lap = self.LAPTOP()
        
    def show(self):
        print(self.name, self.rollno)
        
    class LAPTOP:
        def __init__(self):
            self.brand = 'avita'
            self.cpu = 'i5'
            self.ram = 8
     
s1 = student('a',1) # the moment when we assign the variable we need to assign the class as well 
s2 = student('b',2)

s1.show()
s2.show()

lap1 = s1.lap.cpu
lap2 = s2.lap.ram
lap3 = s2.lap.brand

print(lap1)
print(lap2)
print(lap3)
# Out:
# a 1
# b 2
# i5
# 8
# avita

# %%
#Inheritance

# %%
class A(): 
    def feature1(self):         
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')

a1 = A()  

a1.feature2()
# Out:
# feature2 is hi

# %%
class A(): 
    def feature1(self):         
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')
        
class B(A):
    def feature3(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature4 is hello')
a1 = A()  
b1 = B() 

b1.feature1
# Out:
# <bound method A.feature1 of <__main__.B object at 0x00000295882ACE90>>

# %%
class A(): 
    def feature1(self):         
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')
        
class B(A):
    def feature3(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature4 is hello')

class C(B):
    def feature5():
        print('feature 5 is welcom')

class D(C):
    print('feature6 ')

a1 = A()
b1 = B()
c1 = C()

c1.feature1()
# Out:
# feature6
# feature1 is hi

# %%
class A(): 
    def feature1(self):         
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')
        
class B():
    def feature3(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature4 is hello')

class C(A, B):
    def feature5():
        print('feature 5 is welcom')

a1 = A()
b1 = B()
c1 = C()

c1.feature3
# Out:
# <bound method B.feature3 of <__main__.C object at 0x000002958846A1D0>>
