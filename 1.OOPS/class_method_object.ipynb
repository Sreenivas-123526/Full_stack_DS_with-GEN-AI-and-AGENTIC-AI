# %%
a=5
type(a)
# Out:
# int

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
l=[1,2,2,3,4,5,5]
print(type(l))
# Out:
# <class 'list'>

# %%
def config():
    print('Hello Raghava')
config()
# Out:
# Hello Raghava

# %%
class laptop(): #laptop is class name 
    def config(): #config is method name 
        print('hello team') # statment 

lap = laptop() # lap - object

# %%
class laptop(): 
    def config(): 
        print('hello team') 

lap = laptop() 

laptop.config()
# Out:
# hello team

# %%
class laptop():
    def config():
        print('Hello Sreenu')

lap=laptop()
lap.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       2     def config():
#       3         print('Hello Sreenu')
#       4
#       5 lap=laptop()
# ----> 6 lap.config()
#
# TypeError: laptop.config() takes 0 positional arguments but 1 was given

# %%
class laptop():
    def config(self):
        print('Hello Raghava sons dloitte')

lap=laptop()
lap.config()
# Out:
# Hello Raghava sons dloitte

# %%
class laptop():
    def config(self):
        print('Hello team')

lap=laptop()
lap1=laptop()
lap2=laptop()

lap.config()
lap1.config()
lap2.config()
# Out:
# Hello team
# Hello team
# Hello team

# %%
class computer():
    def config(self):
        print('i5','4gbRAM')

com=computer()
com1=computer()

print(id(com))
print(id(com1))
# Out:
# 2162741154576
# 2162741502480

# %%
class computer():
    def config():
        print('i5','2gb')

a=8.8
print(type(a))

com=computer()
print(type(com))
# Out:
# <class 'float'>
# <class '__main__.computer'>

# %% [markdown]
# SPECIAL METHOD

# %%
class computer():        
    def config(self):      
        print('i5', '8gb')

com1 = computer()

# %%
class computer():
    def __init__(self):
        print('Object created by Raghava')

com=computer()
com1=computer()
# Out:
# Object created by Raghava
# Object created by Raghava

# %%
class computer():
    def __init__(self):
        print('Object created by Raghava')

com=computer()
com1=computer()

com1.__init__()
# Out:
# Object created by Raghava
# Object created by Raghava
# Object created by Raghava

# %%
class computer:        
    
    def __init__(self): #__init__ means initialize the varible
        print('in init')
        
com1 = computer()
com2 = computer()
com3 = computer()
# Out:
# in init
# in init
# in init

# %%
class computer():
    def __init__(self):
        print('Hello Raghava')

    def config(self):
        print('i5','8GB')

com=computer()
# Out:
# Hello Raghava

# %%
class computer():
    def __init__(self):
        print('Hello Raghava')

    def config(self):
        print("sreenivas son")

com=computer()
com.config()
# Out:
# Hello Raghava
# sreenivas son

# %%
class computer():
    def config(self):
        print('Hello Gopala krishna')

    def config1(self):
        print('Hello Raghava')

    def __init__(self):
        print('Helo Sreenivas')

com=computer()
com2 = computer()

com.config()
com.config1()
# Out:
# Helo Sreenivas
# Helo Sreenivas
# Hello Gopala krishna
# Hello Raghava

# %%
class computer():        
    
    def __init__(self): #__init__ means to initialize the variable
        print('in init')
    
    def config(self):     
        print('i5', '8gb')

com1 = computer('i5', 8, 20000) # com1 has cpu i5 & ram is 8 

com1.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 9
#       5
#       6     def config(self):
#       7         print('i5', '8gb')
#       8
# ----> 9 com1 = computer('i5', 8, 20000) # com1 has cpu i5 & ram is 8
#      10
#      11 com1.config()
#
# TypeError: computer.__init__() takes 1 positional argument but 4 were given

# %%
class computer():        
    
    def __init__(self): #__init__ means to initialize the variable
        print('in init')
    
    def config(self):     
        print('i5', '8gb')

com1 = computer('i5', 8) # com1 has cpu i5 & ram is 8 
com2 = computer('i7', 16) # com2 has cpu intel 5 & ram is 8 as we have 2 computer we have different ram & cpt

com1.config() 
com2.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 9
#       5
#       6     def config(self):
#       7         print('i5', '8gb')
#       8
# ----> 9 com1 = computer('i5', 8) # com1 has cpu i5 & ram is 8
#      10 com2 = computer('i7', 16) # com2 has cpu intel 5 & ram is 8 as we have 2 computer we have different ram & cpt
#      11
#      12 com1.config()
#
# TypeError: computer.__init__() takes 1 positional argument but 3 were given

# %%
class computer():
    def config(self):
        print('kignjgn')

    def __init__(self):
        print('3333333333rfv')

com=computer('i5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       4
#       5     def __init__(self):
#       6         print('3333333333rfv')
#       7
# ----> 8 com=computer('i5')
#
# TypeError: computer.__init__() takes 1 positional argument but 2 were given

# %%
class computer():        
    
    def __init__(self,cpu,ram,price ): #__init__ means to initialize the variable
        print('in init')
    
    def config(self):     
        print('i5', '8gb', 5000)

com1 = computer('i5', 8, 50000) # com1 has cpu i5 & ram is 8 
com2 = computer('i7', 16, 60000) # com2 has cpu intel 5 & ram is 8 as we have 2 computer we have different ram & cpt

com1.config() 
com2.config()
# Out:
# in init
# in init
# i5 8gb 5000
# i5 8gb 5000

# %%
class computer():        
     
    def __init__(self,cpu,ram): # cpu & ram as argument
        self.cpu = cpu #hear self is the object & we need to refer to the object
        self.ram = ram 
 
    def config(self):     
        print('config is', self.cpu, self.ram) 

com1 = computer('i5', 8)
com2 = computer('i7', 16)


com1.config() 
com2.config()

#print(id(com1))
#print(id(com2))
# Out:
# config is i5 8
# config is i7 16

# %%
class computer():        
     
    def __init__(self,cpu,ram,price ): # cpu & ram as argument
        self.cpu = cpu #hear self is the object & we need to refer to the object
        self.ram = ram 
        self.price = price
 
    def config(self):     
        print('config is', self.cpu, self.ram, self.price ) 

com1 = computer('i5', 8, 1000)
com2 = computer('i7', 16, 2000)

com1.config() 
com2.config()
# Out:
# config is i5 8 1000
# config is i7 16 2000

# %%
class computer():        
     
    def __init__(self, cpu, ram, price, company ): # cpu & ram as argument
        
        self.cpu = cpu #hear self is the object & we need to refer to the object
        self.ram = ram 
        self.price = price
        self.company= company
 
    def config(self):     
        print('config is', self.cpu, self.ram, self.price , self.company) 

com1 = computer('i5', 8, 1000, 'len' )
com2 = computer('i7', 16, 2000,'hp')

com1.config() 
com2.config()
# Out:
# config is i5 8 1000 len
# config is i7 16 2000 hp

# %%
class computer():
    def __init__(self):
        self.name = 'akash'
        self.age = 37

c1 = computer()
c2 = computer()

print(c1.name,c1.age)
print(c2.name)
# Out:
# akash 37
# akash

# %%
class computer():
    def __init__(self):
        self.name = 'akash'
        self.age = 37

c1 = computer()
c2 = computer()

c2.name = 'ramesh'
c2.age = 45
c1.age = 35

print(c1.name,c1.age)
print(c2.name, c2.age)
# Out:
# akash 35
# ramesh 45
