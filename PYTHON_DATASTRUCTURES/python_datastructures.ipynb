# %% [markdown]
# #LIST

# %%
l=[]
l
# Out:
# []

# %%
L[]
L
# Out:
#   Cell In[2], line 1
#     L[]
#       ^
# SyntaxError: invalid syntax

# %%
type(l)
# Out:
# list

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
l.append
# Out:
# <function list.append(object, /)>

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l
# Out:
# [10, 20]

# %%
l.append(30)
l
# Out:
# [10, 20, 30]

# %%
l.clear()
l
# Out:
# []

# %%
print(l)
# Out:
# []

# %%
l.append(10)
l.append(20)
l.append(30)
l
# Out:
# [10, 20, 30]

# %%
len(l)
# Out:
# 3

# %%
l.copy()
# Out:
# [10, 20, 30]

# %%
l.pop()
l
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 l.pop()
#       2 l
#
# IndexError: pop from empty list

# %%
l1=[10,20,'NIT',set,[1,2]]
l1
# Out:
# [10, 20, 'NIT', set, [1, 2]]

# %%
print(id(l))
print(id(l1))
# Out:
# []
# 2888591656320

# %%
l2=l1.copy()
l2
# Out:
# [10, 20, 'NIT', set, [1, 2]]

# %%
len(l2)
# Out:
# 5

# %%
l2.clear()
l2
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
l2.append(10)
l2.append(20)
l2.append(30)
l2
# Out:
# [10, 20, 30]

# %%
del l2
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 del l2
#       2 l2
#
# NameError: name 'l2' is not defined

# %%
l.append(10)
l.append(20)
l.append(30)
l
# Out:
# [10, 20, 30]

# %%
l.count(200)
# Out:
# 0

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30]
# [10, 20, 'NIT', <class 'set'>, [1, 2]]

# %%
a=[1,2,3]
b=[4,5,6]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
c=[3,4]
d=[6,7]
d.extend(c)
d
# Out:
# [6, 7, 3, 4]

# %%
l.extend(l1)
l
# Out:
# [10, 20, 30, 10, 20, 'NIT', set, [1, 2]]

# %%
l[0]
# Out:
# 10

# %%
l[0]=100
l
# Out:
# [100, 20, 30, 10, 20, 'NIT', set, [1, 2]]

# %%
l.index(20)
# Out:
# 1

# %%
print(l)
# Out:
# [100, 20, 30, 10, 20, 'NIT', <class 'set'>, [1, 2]]

# %%
l[3]=1000000
l
# Out:
# [100, 20, 30, 1000000, 20, 'NIT', set, [1, 2]]

# %%
l[-4]=2222222
l
# Out:
# [100, 20, 30, 1000000, 2222222, 'NIT', set, [1, 2]]

# %%
l.index(30)
# Out:
# 2

# %%
print(l)
# Out:
# [100, 20, 30, 1000000, 2222222, 'NIT', <class 'set'>, [1, 2]]

# %%
l.insert(2,29)
l
# Out:
# [100, 20, 29, 30, 1000000, 2222222, 'NIT', set, [1, 2]]

# %%
l.insert(2,299999922322323232323)
l
# Out:
# [100,
#  20,
#  299999922322323232323,
#  2999999,
#  29,
#  30,
#  1000000,
#  2222222,
#  'NIT',
#  set,
#  [1, 2]]

# %%
print(l)
# Out:
# [100, 20, 299999922322323232323, 2999999, 29, 30, 1000000, 2222222, 'NIT', <class 'set'>, [1, 2]]

# %%
l.pop()
# Out:
# [1, 2]

# %%
print(l)
# Out:
# [100, 20, 299999922322323232323, 2999999, 29, 30, 1000000, 2222222, 'NIT', <class 'set'>]

# %%
l.pop(0)
# Out:
# 100

# %%
print(l)
# Out:
# [20, 299999922322323232323, 2999999, 29, 30, 1000000, 2222222, 'NIT', <class 'set'>]

# %%
l.pop()
# Out:
# set

# %%
l.reverse()
l
# Out:
# [20, 299999922322323232323, 2999999, 29, 30, 1000000, 2222222, 'NIT']

# %%
print(l)
# Out:
# [20, 299999922322323232323, 2999999, 29, 30, 1000000, 2222222, 'NIT']

# %%
l.reverse()
l
# Out:
# ['NIT', 2222222, 1000000, 30, 29, 2999999, 299999922322323232323, 20]

# %%
l.sort()
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 l.sort()
#       2 l
#
# TypeError: '<' not supported between instances of 'int' and 'str'
