# %% [markdown]
# #Python Basics and Data structures(List)

# %%
v=2
v
# Out:
# 2

# %%
1v=3
1v
# Out:
#   Cell In[2], line 1
#     1v=3
#     ^
# SyntaxError: invalid decimal literal

# %%
int v=2
v
# Out:
#   Cell In[3], line 1
#     int v=2
#         ^
# SyntaxError: invalid syntax

# %%
int=3
int
# Out:
# 3

# %%
f=4.3
f
# Out:
# 4.3

# %%
a=2+6J
a
# Out:
# (2+6j)

# %%
a=2j
a
# Out:
# 2j

# %%
a=3
b=2
print(a>b)
# Out:
# True

# %%
a=True
a
# Out:
# True

# %%
a=3
b=3
c=9
print(a<b)
print(a==b)
print(b>c)
# Out:
# False
# True
# False

# %%
a@=2
A
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 a@=2
#       2 A
#
# TypeError: unsupported operand type(s) for @=: 'int' and 'int'

# %%
_a_=3
_a_
# Out:
# 3

# %%
a_+=3
a_
# Out:
# 18

# %%
print('svb')
# Out:
# svb

# %%
at='abc'
at
# Out:
# 'abc'

# %%
len('abcsreenu')
# Out:
# 9

# %%
a=len('sreenu')
a

id(a)
# Out:
# 140707504759880

# %%
type(a)
# Out:
# int

# %%
a=max(1,2,3,3,4,5,5)
print(max(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 a=max(1,2,3,3,4,5,5)
# ----> 2 print(max(a))
#
# TypeError: 'int' object is not iterable

# %%
print(max(1,2,3))
# Out:
# 3

# %%
str='sreenu'
str
# Out:
# 'sreenu'

# %%
str
str[:]
# Out:
# 'sreenu'

# %%
str[0]
# Out:
# 's'

# %%
str[2]
# Out:
# 'e'

# %%
str[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 str[20]
#
# IndexError: string index out of range

# %%
str[1:5]
# Out:
# 'sreenu'

# %%
str[1:5:2]
# Out:
# 're'

# %%
str=('sreenivas')
str
# Out:
# 'sreenivas'

# %%
str[::9]
# Out:
# 's'

# %%
float(2)
# Out:
# 2.0

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 int(1+2j)
#
# TypeError: 'int' object is not callable

# %%
float('set')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 float('set')
#
# ValueError: could not convert string to float: 'set'

# %%
float(2+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 float(2+3j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
complex(10,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 complex(10,2,3)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(1)
# Out:
# (1+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('3')
# Out:
# (3+0j)

# %%
str(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 str(2,3)
#
# TypeError: 'str' object is not callable

# %%
a=2
b=2
c=a//b
print(c)
# Out:
# 1

# %%
x=2
print(x)
x%=4
x
# Out:
# 2
# 2

# %%
x**=2
complex(x)
# Out:
# (1.8446744073709552e+19+0j)

# %%
a=2
b=2
print(a==b or a>b)
# Out:
# True

# %%
a=5
print(-a)
# Out:
# -5

# %%
a='sree'
a
# Out:
# 'sree'

# %%
bin(10)
# Out:
# '0b1010'

# %%
oct(10)
# Out:
# '0o12'

# %%
dec(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 dec(10)
#
# NameError: name 'dec' is not defined

# %%
hex(10)
# Out:
# '0xa'

# %%
float(0b1010)
# Out:
# 10.0

# %%
a=-5
print(~a)
# Out:
# 4

# %%
a=3
b=4
print(a>b and a==b)
# Out:
# False

# %%
a=4
print(~a)
# Out:
# -5

# %%
a=3
b=4
print(a&b)
# Out:
# 0

# %%
print(a|b)
# Out:
# 7

# %%
print(a^b)
# Out:
# 7

# %%
a=4
b=c
c=a+b
print('the sum of {} and {} is {}'.format(a,b,c))
# Out:
# the sum of 4 and 9 is 13

# %%
print(a)
print(b)
print(c)
# Out:
# 4
# 9
# 13

# %%
print(f'the sum of {a} and {b} is {c}')
# Out:
# the sum of 4 and 9 is 13

# %%
print('Manikanta')
print('Sreenivas')
# Out:
# Manikanta
# Sreenivas

# %%
print('Manikanta',end=' ')
print('Sreenivas')
# Out:
# Manikanta Sreenivas

# %%
print('Manikanta',sep='&')
print('Sreenu')
# Out:
# Manikanta
# Sreenu

# %%
print("Manikanta",'Sreenu')
# Out:
# Manikanta Sreenu

# %%
print('Raju','Sree',sep='-')
# Out:
# Raju-Sree

# %%
import math 
math.sqrt(25)
# Out:
# 5.0

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  :q
# No Python documentation found for ':q'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
# help>  q
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# ...

# %%
import math as m
m.pow(5,3)
# Out:
# 125.0

# %%
import math as m
m.sqrt(3)
# Out:
# 1.7320508075688772

# %%
from math import *
m.sqrt(2)
# Out:
# 1.4142135623730951

# %%
from math import pow,sqrt
pow(2,4)
# Out:
# 16.0

# %%
l=[]
l
# Out:
# []

# %%
l.append(10)
l.append(20)
l.append(30)
l
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
l.clear()
l
# Out:
# []

# %%
l
# Out:
# [10, 20, 30]

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 10, 20, 30]
# [10, 20, 30]

# %%
l.count(10)
# Out:
# 1

# %%
l.count(20)
# Out:
# 2

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 10, 20, 30]
# [10, 20, 30]

# %%
l.extend(l1)
l
# Out:
# [10, 20, 30, 10, 20, 30, 10, 20, 30]

# %%
print(l)
print(l1)
# Out:
# [1112222, 20]
# [10, 20, 30]

# %%
l.index(30)
# Out:
# 2

# %%
l.insert(1,1112222)
l
# Out:
# [10, 1112222, 22222, 20, 30, 22222, 10, 20, 30, 10, 20, 30]

# %%
l.pop()
l
# Out:
# [10, 1112222, 22222, 20, 30, 22222, 10, 20]

# %%
l.pop(1)
l
# Out:
# [1112222, 20]

# %%
print(l1)
# Out:
# [10, 20, 30]

# %%
l1.remove(20)
l1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[275], line 1
# ----> 1 l1.remove(10)
#       2 l1
#
# ValueError: list.remove(x): x not in list

# %%
l1.reverse()
l1
# Out:
# [30, 20]

# %%
l.append(10)
l.append(200)
l
# Out:
# [1112222, 10, 200, 10, 200]

# %%
l
# Out:
# [1112222, 10, 200, 10, 200]

# %%
l1
# Out:
# [30, 20]

# %%
l.sort()
l
# Out:
# [10, 10, 200, 200, 1112222]

# %%
l
# Out:
# [10, 10, 200, 200, 1112222]

# %%
l.sort(reverse=True)
l
# Out:
# [1112222, 200, 200, 10, 10]
