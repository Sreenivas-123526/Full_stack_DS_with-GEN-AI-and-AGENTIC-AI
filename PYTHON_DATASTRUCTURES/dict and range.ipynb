# %% [markdown]
# #Dict and Range

# %%
keys={'1','2'}
d1=dict.fromkeys(keys)
d1
# Out:
# {'2': None, '1': None}

# %%
d={}
d
# Out:
# {}

# %%
type(d)
# Out:
# dict

# %%
d={1:'ab',2:'bc',3:'ca',4:'da'}
d
# Out:
# {1: 'ab', 2: 'bc', 3: 'ca', 4: 'da'}

# %%
d
# Out:
# {1: 'ab', 2: 'bc', 3: 'ca', 4: 'da'}

# %%
d.clear()
d
# Out:
# {}

# %%
d={1:'ab',2:'bc',3:'ca',4:'da'}
d
# Out:
# {1: 'ab', 2: 'bc', 3: 'ca', 4: 'da'}

# %%
d1=d.copy()
d1
# Out:
# {1: 'ab', 2: 'bc', 3: 'ca', 4: 'da'}

# %%
d1.fromkeys(keys)
# Out:
# {'b': None, 'a': None, 'c': None}

# %%
keys
# Out:
# {'a', 'b', 'c'}

# %%
d1.get(1)
# Out:
# 'ab'

# %%
d1.items()
# Out:
# dict_items([(1, 'ab'), (2, 'bc'), (3, 'ca'), (4, 'da')])

# %%
d1[19]='nvb'
d1
# Out:
# {1: 'ab', 2: 'bc', 3: 'nvb', 4: 'da', 5: 'nvb', 19: 'nvb'}

# %%
keys={'1','2'}
value=10
d1=dict.fromkeys(keys,value)
d1
# Out:
# {'2': 10, '1': 10}

# %%
keys={'1','2'}
value=10,20,30
d1=dict.fromkeys(keys,value)
d1
# Out:
# {'2': (10, 20, 30), '1': (10, 20, 30)}

# %%
d1.items()
# Out:
# dict_items([('2', (10, 20, 30)), ('1', (10, 20, 30))])

# %%
d1.keys()
# Out:
# dict_keys(['2', '1'])

# %%
d1
# Out:
# {'2': (10, 20, 30), '1': (10, 20, 30)}

# %%
d1.pop('2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 d1.pop('2')
#
# KeyError: '2'

# %%
d1
# Out:
# {'1': (10, 20, 30)}

# %%
d.popitem()
# Out:
# (4, 'da')

# %%
d
# Out:
# {1: 'ab', 2: 'bc', 3: 'ca'}

# %%
d.values()
# Out:
# dict_values(['ab', 'bc', 'ca'])

# %%
d.setdefault(

# %%
keys={'1','2'}
value=[10,20,30]
mydict3=dict.fromkeys(keys,value)
mydict3
# Out:
# {'2': [10, 20, 30], '1': [10, 20, 30]}

# %%
value.append(40)
mydict3
# Out:
# {'2': [10, 20, 30, 40], '1': [10, 20, 30, 40]}

# %%
d
# Out:
# {1: 'ab', 2: 'bc', 3: 'ca'}

# %%
d[2]
# Out:
# 'bc'

# %%
d.setdefault(3,'abcd')
d
# Out:
# {1: 'ab', 2: 'bc', 3: 'ca'}

# %%
d.setdefault(5,'abc')
d
# Out:
# {1: 'ab', 2: 'bc', 3: 'ca', 5: 'abc'}

# %%
print(d)
print(d1)
# Out:
# {1: 'ab', 2: 'bc', 3: 'ca', 5: 'abc'}
# {'2': None, '1': None}

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'b': 3, 'c': 4}

# %%
d1.update(d2)
d1
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
d1.update(c=23,d=22)
d1
# Out:
# {'a': 1, 'b': 3, 'c': 23, 'd': 22}

# %%
data = {'name': 'John'}

data.update({'age': 25, 'city': 'Delhi'})

print(data)
# Out:
# {'name': 'John', 'age': 25, 'city': 'Delhi'}

# %% [markdown]
# #Range

# %%
range(5)
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in list(range(4)):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
list(range(0,20,5))
# Out:
# [0, 5, 10, 15]

# %%
range(0,10,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 range(0,10,2,3)
#
# TypeError: range expected at most 3 arguments, got 4

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 random.rand(4)
#
# NameError: name 'random' is not defined
