# %%
l
l
# Out:
# {}

# %%
keys={'a','b','c','d'}
d1=dict.fromkeys(keys)
d1
# Out:
# {'c': None, 'b': None, 'd': None, 'a': None}

# %%
keys={'a','b'}
d=dict.clear
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 keys={'a','b'}
# ----> 2 d=dict.clear(a)
#
# NameError: name 'a' is not defined

# %%
l={10,20,30}
l
# Out:
# {10, 20, 30}

# %%
l=[]
l
# Out:
# []

# %%
l=[10,20,30,30,49]
l
# Out:
# [10, 20, 30, 30, 49]

# %%
l.append(24)
l
# Out:
# [10, 20, 30, 30, 49, 24]

# %%
l.clear()
l
# Out:
# []

# %%
l
# Out:
# [10, 20, 30, 30, 49]

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30, 30, 49]

# %%
l.count(103903090)
# Out:
# 0

# %%
l.extend(l1)
l
# Out:
# [10, 20, 30, 30, 49, 10, 20, 30, 30, 49]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 30, 49, 10, 20, 30, 30, 49]
# [10, 20, 30, 30, 49]

# %%
l.index(49)
# Out:
# 4

# %%
l.pop()
l
# Out:
# [10, 20, 30, 30, 49, 10, 20]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 30, 49, 10, 20]
# [10, 20, 30, 30, 49]

# %%
l.pop(0)
l
# Out:
# [20, 30, 30, 49, 10, 20]

# %%
l.remove(30)
l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 l.remove(30)
#       2 l
#
# ValueError: list.remove(x): x not in list

# %%
l.reverse()
l
# Out:
# [49, 10, 20]

# %%
l.sort(reverse=True)
l
# Out:
# [49, 20, 10]

# %%
t=()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t=(1,2,3)
t
# Out:
# (1, 2, 3)

# %%
t.count(1)
# Out:
# 1

# %%
t.index(32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 t.index(32)
#
# ValueError: tuple.index(x): x not in tuple

# %%
t.index(3)
# Out:
# 2

# %%
s={}
s
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s={1,2,3,3,4,45,5}
s
# Out:
# {1, 2, 3, 4, 5, 45}

# %%
type(s)
# Out:
# set

# %%
s.add(4.5)
s
# Out:
# {1, 2, 3, 4, 4.5, 5, 10, 34.5, 45}

# %%
s.add('qse')
s
# Out:
# {1, 10, 2, 3, 312, 34.5, 4, 4.5, 45, 5, 'eenu', 'qse', 'sreenu'}

# %%
s.clear()
s
# Out:
# set()

# %%
print(s)
# Out:
# set()

# %%
s={1, 10, 2, 3, 312, 34.5, 4, 4.5, 45, 5, 'eenu', 'qse', 'sreenu'}
s
# Out:
# {1, 10, 2, 3, 312, 34.5, 4, 4.5, 45, 5, 'eenu', 'qse', 'sreenu'}

# %%
s1=s.copy()
s1
# Out:
# {1, 10, 2, 3, 312, 34.5, 4, 4.5, 45, 5, 'eenu', 'qse', 'sreenu'}

# %%
print(s)
print(s1)
# Out:
# {1, 2, 3, 34.5, 4, 4.5, 5, 'eenu', 312, 10, 45, 'qse', 'sreenu'}
# {1, 2, 3, 34.5, 4, 4.5, 5, 'eenu', 312, 10, 45, 'qse', 'sreenu'}

# %%
s.pop(0)
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 s.pop(0)
#       2 s
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s
# Out:
# {2, 3, 312, 34.5, 4, 4.5, 45, 5, 'eenu', 'qse', 'sreenu'}

# %%
s.discard(32222)
s
# Out:
# {312, 34.5, 4, 4.5, 45, 5, 'eenu', 'qse', 'sreenu'}

# %%
s.difference()
s
# Out:
# {312, 34.5, 4, 4.5, 45, 5, 'eenu', 'qse', 'sreenu'}

# %%
txt = "aaaabcdefghiabababaaaaa"
txt
# Out:
# 'aaaabcdefghiabababaaaaa'

# %%
txt
# Out:
# 'aaaabcdefghi '

# %%
txt.strip("a")
# Out:
# 'bcdefghiababab'

# %%
txt
# Out:
# 'aaaabcdefghiabababaaaaa'

# %%
mystr = "My favourite TV Series is \"Game of Thrones\""
mystr
# Out:
# 'My favourite TV Series is "Game of Thrones"'

# %%
l=[]
l
# Out:
# []

# %%
l=[10,2,2,10,2,23,34]
l
# Out:
# [10, 2, 2, 10, 2, 23, 34]

# %%
l[0][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[240], line 1
# ----> 1 l[0][0]
#
# TypeError: 'int' object is not subscriptable

# %%
l=[10, 20, [30, 40, 50], 60]
l
# Out:
# [10, 20, [30, 40, 50], 60]

# %%
l[2][1]
# Out:
# 40

# %%
list1 = ['one', 'two', 'three', 'four']
list2 = ['five', 'six', 'seven', 'eight']

# %%
list3=list1+list2
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
l=[1,2,3,4,4,5,9]
l
print(20 not in l)
# Out:
# True

# %%
l=['sreenu',12,34]

if 'srenu' in l:
    print('person is there')
else:
    print('person is not there')
# Out:
# person is not there

# %%
p=['manikanta','sreenivas','dady','son']
p
# Out:
# ['manikanta', 'sreenivas', 'dady', 'son']

# %%
p=['raghava','son','is','sreenivas']
for i in enumerate(p):
    print(i)
# Out:
# (0, 'raghava')
# (1, 'son')
# (2, 'is')
# (3, 'sreenivas')

# %%
L1 = [0]
L1
# Out:
# [0]

# %%
any(L1)
# Out:
# False

# %%
fruits = ["apple", "banana", "mango"]

for i, fruit in enumerate(fruits):
    print(i, fruit)
# Out:
# 0 apple
# 1 banana
# 2 mango

# %%
x='''2+3'''
x
print(eval(x))
# Out:
# 5
