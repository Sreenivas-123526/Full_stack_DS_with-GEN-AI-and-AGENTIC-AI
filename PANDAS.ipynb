# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df=pd.read_excel(r'C:\Users\hp\Desktop\27 march-Numpy_function_and_image_to_array\dataset1.xlsx')

# %%
df
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244       78.90000
# 1              Afghanistan         AFG     35.253        5.90000
# 2                   Angola         AGO     45.985       19.10000
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# ...

# %%
len(df) #Always gives rows
# Out:
# 20

# %%
df.shape #Always gives dimentions- rows and columns
# Out:
# (20, 5)

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 5

# %%
df
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244       78.90000
# 1              Afghanistan         AFG     35.253        5.90000
# 2                   Angola         AGO     45.985       19.10000
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# ...

# %%
df.isnull()
# Out:
#     CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0         False        False      False          False        False
# 1         False        False      False          False        False
# 2         False        False      False          False        False
# 3         False        False      False          False        False
# 4         False        False      False          False        False
# 5         False        False      False          False        False
# 6         False        False      False          False        False
# 7         False        False      False          False        False
# 8         False        False      False          False        False
# 9         False        False      False          False        False
# 10        False        False      False          False        False
# 11        False        False      False          False        False
# 12        False        False      False          False        False
# ...

# %%
df.isna()
# Out:
#     CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0         False        False      False          False        False
# 1         False        False      False          False        False
# 2         False        False      False          False        False
# 3         False        False      False          False        False
# 4         False        False      False          False        False
# 5         False        False      False          False        False
# 6         False        False      False          False        False
# 7         False        False      False          False        False
# 8         False        False      False          False        False
# 9         False        False      False          False        False
# 10        False        False      False          False        False
# 11        False        False      False          False        False
# 12        False        False      False          False        False
# ...

# %%
for i in df.isnull().sum():
  print(i)
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
id(df)
# Out:
# 2066444202976

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    20 non-null     object
#  1   CountryCode    20 non-null     object
#  2   BirthRate      20 non-null     float64
#  3   InternetUsers  20 non-null     float64
#  4   IncomeGroup    20 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 932.0+ bytes

# %%
df.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
df.head() # System by default prints top 5 rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail() # Bottom 5 rows
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 15              Bangladesh         BGD     20.142        6.63000
# 16                Bulgaria         BGR      9.200       53.06150
# 17                 Bahrain         BHR     15.040       90.00004
# 18                 Bahamas         BHS     15.322       72.00000
# 19  Bosnia and Herzegovina         BIH      9.062       57.79000
#
#             IncomeGroup
# 15  Lower middle income
# 16  Upper middle income
# 17          High income
# 18          High income
# 19  Upper middle income

# %%
df.head(6)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
df.tail(7)
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 13                   Benin         BEN     36.440        4.90000
# 14            Burkina Faso         BFA     40.551        9.10000
# 15              Bangladesh         BGD     20.142        6.63000
# 16                Bulgaria         BGR      9.200       53.06150
# 17                 Bahrain         BHR     15.040       90.00004
# 18                 Bahamas         BHS     15.322       72.00000
# 19  Bosnia and Herzegovina         BIH      9.062       57.79000
#
#             IncomeGroup
# 13           Low income
# 14           Low income
# 15  Lower middle income
# 16  Upper middle income
# 17          High income
# 18          High income
# 19  Upper middle income

# %%
#INDEXING AND SLICING IN PANDAS

# %%
df[:]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244       78.90000
# 1              Afghanistan         AFG     35.253        5.90000
# 2                   Angola         AGO     45.985       19.10000
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# ...

# %%
df[:6]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
df[5:10]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 5            Argentina         ARG     17.716        59.9000
# 6              Armenia         ARM     13.308        41.9000
# 7  Antigua and Barbuda         ATG     16.447        63.4000
# 8            Australia         AUS     13.200        83.0000
# 9              Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df[3:]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# 13                   Benin         BEN     36.440        4.90000
# 14            Burkina Faso         BFA     40.551        9.10000
# 15              Bangladesh         BGD     20.142        6.63000
# ...

# %%
df[0:9:2]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 2                Angola         AGO     45.985           19.1
# 4  United Arab Emirates         ARE     11.044           88.0
# 6               Armenia         ARM     13.308           41.9
# 8             Australia         AUS     13.200           83.0
#
#            IncomeGroup
# 0          High income
# 2  Upper middle income
# 4          High income
# 6  Lower middle income
# 8          High income

# %%
df[0:201:2]
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 0                  Aruba         ABW     10.244        78.9000
# 2                 Angola         AGO     45.985        19.1000
# 4   United Arab Emirates         ARE     11.044        88.0000
# 6                Armenia         ARM     13.308        41.9000
# 8              Australia         AUS     13.200        83.0000
# 10            Azerbaijan         AZE     18.300        58.7000
# 12               Belgium         BEL     11.200        82.1702
# 14          Burkina Faso         BFA     40.551         9.1000
# 16              Bulgaria         BGR      9.200        53.0615
# 18               Bahamas         BHS     15.322        72.0000
#
#             IncomeGroup
# 0           High income
# 2   Upper middle income
# 4           High income
# 6   Lower middle income
# 8           High income
# 10  Upper middle income
# 12          High income
# 14           Low income
# 16  Upper middle income
# ...

# %%
df[::10]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 10  Azerbaijan         AZE     18.300           58.7  Upper middle income

# %%
df[::-3]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 19  Bosnia and Herzegovina         BIH      9.062        57.7900
# 16                Bulgaria         BGR      9.200        53.0615
# 13                   Benin         BEN     36.440         4.9000
# 10              Azerbaijan         AZE     18.300        58.7000
# 7      Antigua and Barbuda         ATG     16.447        63.4000
# 4     United Arab Emirates         ARE     11.044        88.0000
# 1              Afghanistan         AFG     35.253         5.9000
#
#             IncomeGroup
# 19  Upper middle income
# 16  Upper middle income
# 13           Low income
# 10  Upper middle income
# 7           High income
# 4           High income
# 1            Low income

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df['CountryName']
# Out:
# 0                      Aruba
# 1                Afghanistan
# 2                     Angola
# 3                    Albania
# 4       United Arab Emirates
# 5                  Argentina
# 6                    Armenia
# 7        Antigua and Barbuda
# 8                  Australia
# 9                    Austria
# 10                Azerbaijan
# 11                   Burundi
# 12                   Belgium
# 13                     Benin
# 14              Burkina Faso
# 15                Bangladesh
# 16                  Bulgaria
# 17                   Bahrain
# 18                   Bahamas
# 19    Bosnia and Herzegovina
# Name: CountryName, dtype: object

# %%
df[['BirthRate','InternetUsers']]
# Out:
#     BirthRate  InternetUsers
# 0      10.244       78.90000
# 1      35.253        5.90000
# 2      45.985       19.10000
# 3      12.877       57.20000
# 4      11.044       88.00000
# 5      17.716       59.90000
# 6      13.308       41.90000
# 7      16.447       63.40000
# 8      13.200       83.00000
# 9       9.400       80.61880
# 10     18.300       58.70000
# 11     44.151        1.30000
# 12     11.200       82.17020
# 13     36.440        4.90000
# 14     40.551        9.10000
# 15     20.142        6.63000
# 16      9.200       53.06150
# 17     15.040       90.00004
# 18     15.322       72.00000
# 19      9.062       57.79000

# %%
#split the data into categorical and numerical

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df_cat=df[['CountryName', 'CountryCode',
       'IncomeGroup']]
df_cat.head(1)
# Out:
#   CountryName CountryCode  IncomeGroup
# 0       Aruba         ABW  High income

# %%
df_num=df[[ 'BirthRate', 'InternetUsers']]
df_num.head(1)
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9

# %%
print(df.columns)
print()
print(df_cat.columns)
print()
print(df_num.columns)
print()
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')
#
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='object')
#
# Index(['BirthRate', 'InternetUsers'], dtype='object')

# %%
df.describe() #By default describe function provide info of numerical data only
# Out:
#        BirthRate  InternetUsers
# count  20.000000      20.000000
# mean   20.244100      50.678527
# std    12.551024      31.468691
# min     9.062000       1.300000
# 25%    11.161000      16.600000
# 50%    15.181000      58.245000
# 75%    23.919750      79.329700
# max    45.985000      90.000040

# %%
df_num.describe()
# Out:
#        BirthRate  InternetUsers
# count  20.000000      20.000000
# mean   20.244100      50.678527
# std    12.551024      31.468691
# min     9.062000       1.300000
# 25%    11.161000      16.600000
# 50%    15.181000      58.245000
# 75%    23.919750      79.329700
# max    45.985000      90.000040

# %%
df_cat.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count           20          20           20
# unique          20          20            4
# top          Aruba         ABW  High income
# freq             1           1            9

# %%
df
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244       78.90000
# 1              Afghanistan         AFG     35.253        5.90000
# 2                   Angola         AGO     45.985       19.10000
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# ...

# %%
df['InternetUsers']<2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: InternetUsers, dtype: bool

# %%
df[df['InternetUsers']<2]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11     Burundi         BDI     44.151            1.3  Low income

# %%
df[df['BirthRate']>40]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 2         Angola         AGO     45.985           19.1  Upper middle income
# 11       Burundi         BDI     44.151            1.3           Low income
# 14  Burkina Faso         BFA     40.551            9.1           Low income

# %%
len(df[df['BirthRate']>40])
# Out:
# 3

# %%
df[(df.BirthRate>40)&(df.InternetUsers<2)]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11     Burundi         BDI     44.151            1.3  Low income

# %%
df['IncomeGroup']=='High income'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19    False
# Name: IncomeGroup, dtype: bool

# %%
df[df['IncomeGroup']=='High income']
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                  Aruba         ABW     10.244       78.90000  High income
# 4   United Arab Emirates         ARE     11.044       88.00000  High income
# 5              Argentina         ARG     17.716       59.90000  High income
# 7    Antigua and Barbuda         ATG     16.447       63.40000  High income
# 8              Australia         AUS     13.200       83.00000  High income
# 9                Austria         AUT      9.400       80.61880  High income
# 12               Belgium         BEL     11.200       82.17020  High income
# 17               Bahrain         BHR     15.040       90.00004  High income
# 18               Bahamas         BHS     15.322       72.00000  High income

# %%
df['IncomeGroup'].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
df['IncomeGroup'].nunique()
# Out:
# 4

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.columns=['a','b','c','d','e']
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.columns=['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']
df.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
df.BirthRate*df.InternetUsers
# Out:
# 0      808.251600
# 1      207.992700
# 2      878.313500
# 3      736.564400
# 4      971.872000
# 5     1061.188400
# 6      557.605200
# 7     1042.739800
# 8     1095.600000
# 9      757.816720
# 10    1074.210000
# 11      57.396300
# 12     920.306240
# 13     178.556000
# 14     369.014100
# 15     133.541460
# 16     488.165800
# 17    1353.600597
# 18    1103.184000
# 19     523.692980
# dtype: float64

# %%
df['myCalc']=df.BirthRate*df.InternetUsers
df['myCalc']
# Out:
# 0      808.251600
# 1      207.992700
# 2      878.313500
# 3      736.564400
# 4      971.872000
# 5     1061.188400
# 6      557.605200
# 7     1042.739800
# 8     1095.600000
# 9      757.816720
# 10    1074.210000
# 11      57.396300
# 12     920.306240
# 13     178.556000
# 14     369.014100
# 15     133.541460
# 16     488.165800
# 17    1353.600597
# 18    1103.184000
# 19     523.692980
# Name: myCalc, dtype: float64

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    myCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'myCalc'],
#       dtype='object')

# %%
df=df.drop('myCalc',axis=1) # axis=0 for rows and axis=1 for colums
df
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244       78.90000
# 1              Afghanistan         AFG     35.253        5.90000
# 2                   Angola         AGO     45.985       19.10000
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# ...

# %%
df['InternetUsers'].unique()
# Out:
# array([78.9      ,  5.9      , 19.1      , 57.2      , 88.       ,
#        59.9      , 41.9      , 63.4      , 83.       , 80.6188   ,
#        58.7      ,  1.3      , 82.1702   ,  4.9      ,  9.1      ,
#         6.63     , 53.0615   , 90.0000397, 72.       , 57.79     ])

# %%
df['InternetUsers'].nunique()
# Out:
# 20

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize']=6,2 #reduce the figure size(width,height)

import warnings
warnings.filterwarnings('ignore')#os error

# %%
df['InternetUsers']
# Out:
# 0     78.90000
# 1      5.90000
# 2     19.10000
# 3     57.20000
# 4     88.00000
# 5     59.90000
# 6     41.90000
# 7     63.40000
# 8     83.00000
# 9     80.61880
# 10    58.70000
# 11     1.30000
# 12    82.17020
# 13     4.90000
# 14     9.10000
# 15     6.63000
# 16    53.06150
# 17    90.00004
# 18    72.00000
# 19    57.79000
# Name: InternetUsers, dtype: float64

# %%
vis1=sns.distplot(df['InternetUsers'])#Distribution plot

# %%
vis2=sns.displot(df['InternetUsers'])

# %%
vis3=sns.distplot(df['InternetUsers'],bins=10)

# %%
#BOX PLOTS
vis4=sns.boxplot(data=df,x="IncomeGroup",y="BirthRate") #BI-VARIATE ANALYSIS 


#In the below grapgh circle is called outlier

# %%
#refer to the box_plt_pic in desktop

# %%
vis5=sns.lmplot(data=df,x='InternetUsers',y='BirthRate') #LINEAR MODEL PLOT

# %%
vis6=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=False) #Regressions line is missing here

# %%
vis7=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=False,hue='IncomeGroup') 
#Hue - paramter for color

# %%
vis8=sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=True,hue='IncomeGroup')
