# %%
pip install -U langchain-google-genai
# Out:
# ...
#
#    ---------------------------------------- 0/2 [filetype]
#    ---------------------------------------- 0/2 [filetype]
#    ---------------------------------------- 0/2 [filetype]
#    ---------------------------------------- 0/2 [filetype]
#    -------------------- ------------------- 1/2 [langchain-google-genai]
#    -------------------- ------------------- 1/2 [langchain-google-genai]
#    -------------------- ------------------- 1/2 [langchain-google-genai]
#    ---------------------------------------- 2/2 [langchain-google-genai]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"]="AIzaSyBTClG3UJecxya-jAFXDwYZE0t0SerEJ4w"  #os.environ is a dictionary containing environment variables.

model=init_chat_model("google_genai:gemini-3-flash-preview")

# %%
response=model.invoke("Job opportunity in 2027 in Gen AI and Agentic AI")

# %%
print(response)
# Out:
# content=[{'type': 'text', 'text': 'By 2027, the landscape of Generative AI (GenAI) will have shifted from **"Chatting with Models"** to **"Managing Autonomous Agents."** We are currently in the era of experimentation; by 2027, we will be in the era of **Agentic Workflows**—where AI doesn\'t just suggest text, but executes complex, multi-step business processes with minimal human oversight.\n\nHere is a breakdown of the job opportunities, emerging roles, and essential skills for 2027.\n\n---\n\n### 1. High-Demand Job Roles in 2027\n\n#### A. AI Agent Architect / Orchestrator\nThis role replaces the "Prompt Engineer." Instead of writing single prompts, you will design "swarms" of agents. You’ll define how a "Manager Agent" assigns tasks to "Worker Agents" (e.g., one for coding, one for testing, one for documentation) to complete a project.\n*   **Focus:** Workflow logic, error handling between agents, and memory management.\n\n#### B. AI Trust, Safety & Compliance Officer\nWith the EU 
# ...

# %%
print(response.text)
# Out:
# By 2027, the landscape of Generative AI (GenAI) will have shifted from **"Chatting with Models"** to **"Managing Autonomous Agents."** We are currently in the era of experimentation; by 2027, we will be in the era of **Agentic Workflows**—where AI doesn't just suggest text, but executes complex, multi-step business processes with minimal human oversight.
#
# Here is a breakdown of the job opportunities, emerging roles, and essential skills for 2027.
#
# ---
#
# ### 1. High-Demand Job Roles in 2027
#
# #### A. AI Agent Architect / Orchestrator
# This role replaces the "Prompt Engineer." Instead of writing single prompts, you will design "swarms" of agents. You’ll define how a "Manager Agent" assigns tasks to "Worker Agents" (e.g., one for coding, one for testing, one for documentation) to complete a project.
# *   **Focus:** Workflow logic, error handling between agents, and memory management.
#
# #### B. AI Trust, Safety & Compliance Officer
# ...

# %%
#LANGUAGE TRANSLATION

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages=[
    SystemMessage("Please translate below english to odia"),
    HumanMessage("How are u teams working on lanchain using gemini"),
]
model.invoke(messages)
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'ଏହାର ଓଡ଼ିଆ ଅନୁବାଦ ହେଉଛି:\n\n**"Gemini ବ୍ୟବହାର କରି LangChain ଉପରେ ଆପଣଙ୍କ ଟିମ୍ କିପରି କାମ କରୁଛନ୍ତି?"**\n\n(In Odia script: **Gemini ବ୍ୟବହାର କରି LangChain ଉପରେ ଆପଣଙ୍କ ଟିମ୍ କିପରି କାମ କରୁଛନ୍ତି?**)', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fd89b-ff13-7f11-bd61-7877314cea6e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 459, 'total_tokens': 479, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 360}})

# %%
response1=model.invoke(messages)

# %%
print(response1.text)
# Out:
# ଏହାର ଓଡ଼ିଆ ଅନୁବାଦ ହେଉଛି:
#
# **"Gemini ବ୍ୟବହାର କରି LangChain ଉପରେ ଆପଣଙ୍କ ଟିମ୍ କିପରି କାମ କରୁଛନ୍ତି?"**

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages=[
    SystemMessage("Please translate below english to Hindi"),
    HumanMessage("How are u teams working on lanchain using gemini"),
]
model.invoke(messages)
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'आपकी टीमें Gemini का उपयोग करके LangChain पर कैसे काम कर रही हैं?\n\n(Aapki teams Gemini ka upyog karke LangChain par kaise kaam kar rahi hain?)', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fd89e-5fbb-7990-9cfa-3fa67b57db7b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 443, 'total_tokens': 462, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 406}})

# %%
response2=model.invoke(messages)

# %%
print(response2.text)
# Out:
# इसका हिंदी अनुवाद होगा:
#
# **"आपकी टीमें Gemini का उपयोग करके LangChain पर कैसे काम कर रही हैं?"**
#
# (Note: यहाँ 'lanchain' को 'LangChain' समझा गया है, जो एक प्रसिद्ध AI फ्रेमवर्क है।)
