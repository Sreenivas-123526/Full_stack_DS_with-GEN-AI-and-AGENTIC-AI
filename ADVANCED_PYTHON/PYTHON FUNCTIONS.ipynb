# %%
def gree():#user defined the function name without arguments

    print('Good morning') #statement
gree() #user call the function
# Out:
# Good morning

# %%
def sreenu():
    print('Hello')
sreenu
# Out:
# <function __main__.sreenu()>

# %%
def sreenu():
    print('Hello')
sreenu()

def sreenu():
    print('Hello')
sreenu()
# Out:
# Hello
# Hello

# %%
def sreenu():
    print('Hello')
sreenu()
sreenu()
sreenu()
# Out:
# Hello
# Hello
# Hello

# %%
def add(x,y):# x and y are called formal argument
    c=x+y
    print(c)
add(4,5) # 4 and 5 are called actual argument
# Out:
# 9

# %%
def add(x,y):
    c=x+y
    print(c)
add(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(5)
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
def add(x):
    c=x+y
    print(c)
add(5,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(5,9)
#
# TypeError: add() takes 1 positional argument but 2 were given

# %%
def add(x,y):
    c=x+y
    print(c)
add(5,9)
# Out:
# 14

# %%
def add(x,y):
    c=x+y
    return c
add(5,9)
# Out:
# 14

# %%
def add(x,y):
    c=x+y
    print(c)
result=add(5,9)
print(result)
print(type(result))
# Out:
# 14
# None
# <class 'NoneType'>

# %%
def add(x,y):
    c=x+y
    return c
result1=add(5,9)
print(result1)
print(type(result1))
# Out:
# 14
# <class 'int'>

# %%
def sreenu():
    #print('Hello')
    return('Hello')

def add(x,y):
    c=x+y
    return c
def sub(x,y):
    c=x-y 
    return c

r=sreenu()
r1=add(4,3)
r2=sub(4,3)

print(r)
print(r1)
print(r2)
# Out:
# Hello
# 7
# 1

# %%
def add_sub(x,y):
    c=x+y
    d=x-y
    return c,d

result=add_sub(5,7)
print(result)
print(type(result))
# Out:
# (12, -2)
# <class 'tuple'>

# %%
def add_sub(x,y):
    c=x+y
    d=x-y
    return c,d

r,r1=add_sub(5,7)
print(r)
print(r1)

print(type(r))
print(type(r1))
# Out:
# 12
# -2
# <class 'int'>
# <class 'int'>

# %%
def add_sub_mul(x,y):
    c=x+y
    d=x-y
    e=x*y 
    return c,d,e

r,r1,r2=add_sub_mul(5,7)
print(r)
print(r1)
print(r2)


print(type(r))
print(type(r1))
print(type(r2))
# Out:
# 12
# -2
# 35
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
#positional argument
def person(name,age):
    print(name)
    print(age)

person('nit',23)
# Out:
# nit
# 23

# %%
#positional argument
def person(name,age):
    print(name)
    print(age)

person(23,'nit')
# Out:
# 23
# nit

# %%
#positional argument
def person(name,age):
    print(name)
    print(age+1)

person(23,'nit')
# Out:
# 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 6
#       3     print(name)
#       4     print(age+1)
# ----> 6 person(23,'nit')
#
# Cell In[40], line 4, in person(name, age)
#       2 def person(name,age):
#       3     print(name)
# ----> 4     print(age+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Keyword argument
def person(name,age):
    print(name)
    print(age+1)

person(age=23,name='nit')
# Out:
# nit
# 24

# %%
def person(name,age,age2):
    print(name)
    print(age)
    print(age2)

person(age=23,'nit',10)
# Out:
#   Cell In[43], line 6
#     person(age=23,'nit',10)
#                           ^
# SyntaxError: positional argument follows keyword argument

# %%
def person(name,age,age2):
    print(name)
    print(age)
    print(age2)

person(age=23,name='nit',age2=10)
# Out:
# nit
# 23
# 10

# %%
#default argument
def person(name,age):
    print(name)
    print(age)

person('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 6
#       3     print(name)
#       4     print(age)
# ----> 6 person('nit')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
#default argument
def person(name,age=18):
    print(name)
    print(age)

person('nit')
# Out:
# nit
# 18

# %%
#default argument
def person(name,age=18):
    print(name)
    print(age)

person('nit',20)
# Out:
# nit
# 20

# %%
#variable length argument(args)
def sum(a,b):
    c=a+b
    print(c)

sum(5,6,7,8,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 6
#       3     c=a+b
#       4     print(c)
# ----> 6 sum(5,6,7,8,9)
#
# TypeError: sum() takes 2 positional arguments but 5 were given

# %%
#variable length argument(args)
def sum(a,*b):
    c=a+b
    print(c)

sum(5,6,7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 6
#       3     c=a+b
#       4     print(c)
# ----> 6 sum(5,6,7,8)
#
# Cell In[54], line 3, in sum(a, *b)
#       2 def sum(a,*b):
# ----> 3     c=a+b
#       4     print(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
#variable length argument(args)
def sum(a,*b):
    print(a)
    print(b)

sum(5,6,7,8)
# Out:
# 5
# (6, 7, 8)

# %%
#variable length argument(args)
def sum(a,*b):
    print(type(a))
    print(type(b))

sum(5,6,7,8)
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
def sum(a,*b):  #1st arg is fixed and we fetch the each value from the tuple & we can add them
    c=a

    for i in b:
        c=c+i
    print(c)

sum(5,6,7,8)
# Out:
# 26

# %%
#kwargs(keyword+args)
def person():
    person('ALEX',36,'JOHN',98778)
person()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 4
#       2 def person():
#       3     person('ALEX',36,'JOHN',98778)
# ----> 4 person()
#
# Cell In[67], line 3, in person()
#       2 def person():
# ----> 3     person('ALEX',36,'JOHN',98778)
#
# TypeError: person() takes 0 positional arguments but 4 were given

# %%
def person(name,*data):
    print(name)
    print(data)

person('ALEX',36,'JOGN',3435)
# Out:
# ALEX
# (36, 'JOGN', 3435)

# %%
def person(name,*data):
    print('name')
    print(data)

person('ALEX',36,age=23,house='india',mob=92873458)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 5
#       2     print('name')
#       3     print(data)
# ----> 5 person('ALEX',36,age=23,house='india',mob=92873458)
#
# TypeError: person() got an unexpected keyword argument 'age'

# %%
def person(name,**data):
    print('name')
    print(data)

person('ALEX',age=23,house='india',mob=92873458)
# Out:
# name
# {'age': 23, 'house': 'india', 'mob': 92873458}

# %%
#Local variable and global variable
# Out:
# 10

# %%
a=10
print(a)
# Out:
# 10

# %%
a=10   #global variable

def something():

    b=15  #local variable

# %%
a=10

def something():
    b=15
    print('In function',b)
something()
print('Out function',a)
# Out:
# In function 15
# Out function 10

# %%
a=10

def something():
    global a
    b=15
    print('In function',b)
    print('Gobal var',a)
something()
print('Out function',a)
# Out:
# In function 15
# Gobal var 10
# Out function 10

# %%
x=10   # Global variable

def update_x():
    globals()['x']+=6  #access and modify teh global variable using the dictionary

update_x()
print('output is',x)
# Out:
# output is 16

# %%
#Pass list to function
lst=[2,3,4,5,6,7,8,9,10]

# %%
def count(lst):
    even=0
    odd=0
    for i in lst:
        if i%2==0:
            even+=1
        else:
            odd+=1
    return even,odd
lst=[1,2,3,4,5,6,11111]
even,odd=count(lst)

print('even num-{} and odd num-{}'.format(even,odd))
# Out:
# even num-3 and odd num-4

# %%
#Fibanoci series

def fibonaci(n):
    a=0
    b=1
    for i in range(0,n):
        c=a+b
        b=c
        a=b
        print(c)

fibonaci(10)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512

# %%
#Factorial of a number in python
def fac(n):
    f=1
    for i in range(1,n+1):
        f=f*i

    return f
x=4
result=fac(x)
print(result)
# Out:
# 24

# %%
#Recursion
def wish():
    print('hello')
    print('ok')
    wish()
wish()
# Out:
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ok
# hello
# ...

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000

# %%
import sys
sys.setrecursionlimit(200)
print(sys.getrecursionlimit())
# Out:
# 200

# %%
def wish():
    print('hello')
    wish()
wish()
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
import sys
sys.getrecursionlimit()
# Out:
# 200

# %%
import sys
sys.setrecursionlimit(100)
print(sys.getrecursionlimit())

i=0

def wish():
    global i
    i+=1
    print('hello',i)
    wish()

wish()
# Out:
# 100
# hello 1
# hello 2
# hello 3
# hello 4
# hello 5
# hello 6
# hello 7
# hello 8
# hello 9
# hello 10
# hello 11
# hello 12
# hello 13
# hello 14
# hello 15
# hello 16
# hello 17
# hello 18
# hello 19
# hello 20
# hello 21
# hello 22
# hello 23
# hello 24
# hello 25
# hello 26
# hello 27
# hello 28
# hello 29
# hello 30
# hello 31
# hello 32
# hello 33
# hello 34
# hello 35
# hello 36
# hello 37
# hello 38
# hello 39
# hello 40
# hello 41
# hello 42
# hello 43
# hello 44
# hello 45
# hello 46
# hello 47
# hello 48
# hello 49
# hello 50
# hello 51
# hello 52
# hello 53
# hello 54
# hello 55
# hello 56
# hello 57
# hello 58
# hello 59
# hello 60
# hello 61
# hello 62
# hello 63
# hello 64
# hello 65
# hello 66
# hello 67
# hello 68
# hello 69
# hello 70
# hello 71
# hello 72
# hello 73
# hello 74
# hello
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[64], line 13
# ...

# %%
#Factorial using recursion
def fact(n):
    if n==0:
        return 1
    return n*fact(n-1)
result=fact(5)

result
# Out:
# 120

# %%
#LAMBDA FUNCTIONS

# %%
def square(a):
    return a*a
result=square(5)
print(result)
# Out:
# 25

# %%
f=lambda a:a*a
r=f(5)
print(r)
# Out:
# 25

# %%
f=lambda a,b:a+b
f1=lambda a,b:a-b
r=f(4,2)
r1=f1(5,3)
print('{} and {}'.format(r,r1))
# Out:
# 6 and 2

# %%
def is_even(n):
    return n%2==0
nums=[3,4,5,6,7,6]
evens=list(filter(is_even,nums))

print(evens)
# Out:
# [4, 6, 6]

# %%
def is_odd(n):
    return n%2!=0
nums=[1,2,3,4,5,6,7]
odd=list(filter(is_odd,nums))
print(odd)
# Out:
# [1, 3, 5, 7]

# %%
nums=[3,2,3,4,5,6,7,8,90]
evens=list(filter(lambda n:n%2==0,nums))
print(evens)
# Out:
# [2, 4, 6, 8, 90]

# %%
nums=[0,2,3,4,54,5,67,7,7,8,95]
odd=list(filter(lambda n:n%2!=0,nums))
print(odd)
# Out:
# [3, 5, 67, 7, 7, 95]

# %%
def update(n):
    return n-2
nums=[1,2,3,4,5,6,6,7,40]
evens=list(filter(lambda n:n%2==0,nums))
double=list(map(update,evens))
print(evens)
print(double)
# Out:
# [2, 4, 6, 6, 40]
# [0, 2, 4, 4, 38]

# %%
nums=[2,34,4,5,6,7,8,87,34,5,6,67,5]

evens=list(filter(is_even,nums))
double=list(map(lambda n:n*2,evens))
print(evens)
print(double)
# Out:
# [2, 34, 4, 6, 8, 34, 6]
# [4, 68, 8, 12, 16, 68, 12]

# %%
nums=[2,34,4,5,6,7,8,87,34,5,6,67,5]

evens=list(filter(is_even,nums))

double=list(map(lambda n:n*2,evens))
double_1=list(map(lambda n:n+2,evens))
double_2=list(map(lambda n:n-2,evens))

print(evens)
print(double)
print(double_1)
print(double_2)
# Out:
# [2, 34, 4, 6, 8, 34, 6]
# [4, 68, 8, 12, 16, 68, 12]
# [4, 36, 6, 8, 10, 36, 8]
# [0, 32, 2, 4, 6, 32, 4]

# %%
from functools import reduce

def add_all(a,b):
    return a+b
nums=[1,3,4,5,5,34,2,2,43]

evens=list(filter(is_even,nums))
double=list(map(lambda n:n*2,evens))

sums=reduce(add_all,double)
sums
print(sums)
# Out:
# 84

# %%
from functools import reduce
nums=[1,2,3,45,5,65,4,323,98]

evens=list(filter(is_even,nums))
double=list(map(lambda n:n*2,evens))
sums=(reduce(lambda a,b:a+b,double))

print(evens)
print(double)
print(sums)
# Out:
# [2, 4, 98]
# [4, 8, 196]
# 208

# %%
#PYTHON DECORATORS

def div(a,b):
    print(a // b)
div(4,2)
# but what if we pass the value 2, 4
# Out:
# 2

# %%
def div(a, b):
    print(a // b)
div(2,4)
# Out:
# 0

# %%
def div(a,b):
    
    if a<b:
        a,b = b,a
    print(a // b)
    
div(2, 4)
# Out:
# 2

# %%
# using help of the decorator you can add the extra feature in the exicting function 

def div(a,b):
    print(a / b)

def div_decorator(func): # hear div_dectorator will accept the div function
    def inner(a,b):
        if a<b:
            a,b = b,a
        return func(a,b)
    return inner

div = div_decorator(div)

div(2,4)

# %%
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper


@my_decorator
def say_hello():
    print("Hello!")

say_hello()
# Out:
# Something is happening before the function is called.
# Hello!
# Something is happening after the function is called.
